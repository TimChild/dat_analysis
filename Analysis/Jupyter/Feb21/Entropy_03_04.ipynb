# %%
# Add PyDatAnalysis to path
import sys
# insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1, "/Users/owensheekey/Documents/Research/PyDatAnalysis")

export_path = 'Exports/'

# %%
from __future__ import annotations
from src.DatObject.Make_Dat import get_dat, get_dats
import src.UsefulFunctions as U
from src.DataStandardize.ExpSpecific.Feb21 import Feb21Exp2HDF, Feb21ExpConfig
from src.DataStandardize.ExpConfig import ExpConfigGroupDatAttribute, ExpConfigBase
import multiprocessing as mp
import plotly.graph_objs as go
import numpy as np
import lmfit as lm
from typing import TYPE_CHECKING, Iterable, Optional

# %%
datnums = range(1497, 1501)
dats = get_dats(datnums)

# %%
dats[0].SquareEntropy.avg_entropy_signal
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-c9d76c039763> in <module>
# ----> 1 dats[0].SquareEntropy.avg_entropy_signal
#
# ~/Documents/Research/PyDatAnalysis/src/DatObject/Attributes/SquareEntropy.py in avg_entropy_signal(self)
#     151     def avg_entropy_signal(self) -> np.ndarray:
#     152         """Default averaged entropy signal for Square Entropy"""
# --> 153         return self.default_Output.average_entropy_signal
#     154
#     155     def get_Inputs(self,
#
# ~/Documents/Research/PyDatAnalysis/src/DatObject/Attributes/SquareEntropy.py in default_Output(self)
#     136     @property
#     137     def default_Output(self) -> Output:
# --> 138         return self.get_Outputs()
#     139
#     140     @property
#
# ~/Documents/Research/PyDatAnalysis/src/DatObject/Attributes/SquareEntropy.py in get_Outputs(self, name, inputs, process_params, overwrite, existing_only)
#     337
#     338         if not inputs:
# --> 339             inputs = self.get_Inputs()
#     340         if not process_params:
#     341             process_params = self.get_ProcessParams()
#
# ~/Documents/Research/PyDatAnalysis/src/DatObject/Attributes/SquareEntropy.py in get_Inputs(self, name, x_array, i_sense, num_steps, num_cycles, setpoint_lengths, full_wave_masks, centers, avg_nans, save_name)
#     203         if not inp:  # If not found above then create a new inp
#     204             if any([v is None for v in [num_steps, num_cycles, setpoint_lengths, full_wave_masks]]):
# --> 205                 awg = self.square_awg
#     206                 if not num_steps:
#     207                     num_steps = awg.info.num_steps
#
# ~/Documents/Research/PyDatAnalysis/src/DatObject/Attributes/SquareEntropy.py in square_awg(self)
#     115         """
#     116         if not self._square_awg:
# --> 117             awg = copy.copy(self.dat.AWG)
#     118
#     119             # Try to prevent this overwriting real AWG info in HDF by removing set methods
#
# ~/Documents/Research/PyDatAnalysis/src/DatObject/DatHDF.py in AWG(self)
#     291     @property
#     292     def AWG(self) -> A.AWG:
# --> 293         return self._dat_attr_prop('AWG')
#     294
#     295     @AWG.setter
#
# ~/Documents/Research/PyDatAnalysis/src/DatObject/DatHDF.py in _dat_attr_prop(self, name)
#      60         private_key = _get_private_key(name)
#      61         if not getattr(self, private_key, None):
# ---> 62             setattr(self, private_key, DAT_ATTR_DICT[name](self))
#      63         return getattr(self, private_key)
#      64
#
# ~/Documents/Research/PyDatAnalysis/src/DatObject/Attributes/AWG.py in __init__(self, dat)
#      23     def __init__(self, dat: DatHDF):
#      24         self._info = None  # Used in some of the initializations so needs to be above super()
# ---> 25         super().__init__(dat)
#      26         self._AWs = None
#      27         self._freq = None
#
# ~/Documents/Research/PyDatAnalysis/src/DatObject/Attributes/DatAttribute.py in __init__(self, dat)
#      99         self.dat: DatHDF = dat  # Save pointer to parent DatHDF object
#     100         self.hdf: HDU.HDFContainer = dat.hdf
# --> 101         self.check_init()  # Ensures in minimally initialized state
#     102
#     103     @property
#
# ~/Documents/Research/PyDatAnalysis/src/HDF_Util.py in wrapper(*args, **kwargs)
#    1426         container = _get_obj_hdf_container(self)
#    1427         wrapped_func = container.function_wrapper(func, mode_=mode_, group_name=getattr(self, 'group_name', None))  # TODO: Just need to make sure container.set_group is called!
# -> 1428         ret = wrapped_func(*args, **kwargs)
#    1429         # ret = func(*args, **kwargs)
#    1430         return ret
#
# ~/Documents/Research/PyDatAnalysis/src/HDF_Util.py in wrapper(*args, **kwargs)
#    1075                         ret = call_func(*args, **kwargs)
#    1076                 elif mode == 'r':
# -> 1077                     ret = call_func(*args, **kwargs)
#    1078                 else:
#    1079                     raise NotImplementedError
#
# ~/Documents/Research/PyDatAnalysis/src/HDF_Util.py in call_func(*args, **kwargs)
#    1015         def call_func(*args, **kwargs):
#    1016             self.set_group(group_name=group_name)
# -> 1017             return func(*args, **kwargs)
#    1018
#    1019         def wrapper(*args, **kwargs):
#
# ~/Documents/Research/PyDatAnalysis/src/DatObject/Attributes/DatAttribute.py in check_init(self)
#     158             group = self.hdf.get(self.group_name)
#     159         if group.attrs.get('initialized', False) is False:
# --> 160             self._initialize()
#     161
#     162     @with_hdf_write
#
# ~/Documents/Research/PyDatAnalysis/src/HDF_Util.py in wrapper(*args, **kwargs)
#    1426         container = _get_obj_hdf_container(self)
#    1427         wrapped_func = container.function_wrapper(func, mode_=mode_, group_name=getattr(self, 'group_name', None))  # TODO: Just need to make sure container.set_group is called!
# -> 1428         ret = wrapped_func(*args, **kwargs)
#    1429         # ret = func(*args, **kwargs)
#    1430         return ret
#
# ~/Documents/Research/PyDatAnalysis/src/HDF_Util.py in wrapper(*args, **kwargs)
#    1067                             with h5py.File(self.hdf_path, 'r+') as f:
#    1068                                 self.hdf = f
# -> 1069                                 ret = call_func(*args, **kwargs)  # Call the function
#    1070                         finally:
#    1071                             self.hdf = h5py.File(self.hdf_path, 'r')
#
# ~/Documents/Research/PyDatAnalysis/src/HDF_Util.py in call_func(*args, **kwargs)
#    1015         def call_func(*args, **kwargs):
#    1016             self.set_group(group_name=group_name)
# -> 1017             return func(*args, **kwargs)
#    1018
#    1019         def wrapper(*args, **kwargs):
#
# ~/Documents/Research/PyDatAnalysis/src/DatObject/Attributes/DatAttribute.py in _initialize(self)
#     162     @with_hdf_write
#     163     def _initialize(self):
# --> 164         self.initialize_minimum()
#     165         self._write_default_group_attrs()
#     166         assert self.initialized == True
#
# ~/Documents/Research/PyDatAnalysis/src/DatObject/Attributes/AWG.py in initialize_minimum(self)
#     136
#     137     def initialize_minimum(self):
# --> 138         self._copy_info_from_logs()
#     139         self._copy_AW_descriptors()
#     140         self.initialized = True
#
# ~/Documents/Research/PyDatAnalysis/src/DatObject/Attributes/AWG.py in _copy_info_from_logs(self)
#     141
#     142     def _copy_info_from_logs(self):
# --> 143         awg_tuple: AWGtuple = self.dat.Logs.awg
#     144         if awg_tuple is None:
#     145             raise HDU.NotFoundInHdfError(f'AWG info not found in dat.Logs')
#
# ~/Documents/Research/PyDatAnalysis/src/DatObject/DatHDF.py in Logs(self)
#     327     @property
#     328     def Logs(self) -> L.Logs:
# --> 329         return self._dat_attr_prop('Logs')
#     330
#     331     @Logs.setter
#
# ~/Documents/Research/PyDatAnalysis/src/DatObject/DatHDF.py in _dat_attr_prop(self, name)
#      60         private_key = _get_private_key(name)
#      61         if not getattr(self, private_key, None):
# ---> 62             setattr(self, private_key, DAT_ATTR_DICT[name](self))
#      63         return getattr(self, private_key)
#      64
#
# ~/Documents/Research/PyDatAnalysis/src/DatObject/Attributes/Logs.py in __init__(self, dat)
#      69
#      70     def __init__(self, dat: DatHDF):
# ---> 71         super().__init__(dat)
#      72         self._srss = None
#      73         self._mags = None
#
# ~/Documents/Research/PyDatAnalysis/src/DatObject/Attributes/DatAttribute.py in __init__(self, dat)
#      99         self.dat: DatHDF = dat  # Save pointer to parent DatHDF object
#     100         self.hdf: HDU.HDFContainer = dat.hdf
# --> 101         self.check_init()  # Ensures in minimally initialized state
#     102
#     103     @property
#
# ~/Documents/Research/PyDatAnalysis/src/HDF_Util.py in wrapper(*args, **kwargs)
#    1426         container = _get_obj_hdf_container(self)
#    1427         wrapped_func = container.function_wrapper(func, mode_=mode_, group_name=getattr(self, 'group_name', None))  # TODO: Just need to make sure container.set_group is called!
# -> 1428         ret = wrapped_func(*args, **kwargs)
#    1429         # ret = func(*args, **kwargs)
#    1430         return ret
#
# ~/Documents/Research/PyDatAnalysis/src/HDF_Util.py in wrapper(*args, **kwargs)
#    1075                         ret = call_func(*args, **kwargs)
#    1076                 elif mode == 'r':
# -> 1077                     ret = call_func(*args, **kwargs)
#    1078                 else:
#    1079                     raise NotImplementedError
#
# ~/Documents/Research/PyDatAnalysis/src/HDF_Util.py in call_func(*args, **kwargs)
#    1015         def call_func(*args, **kwargs):
#    1016             self.set_group(group_name=group_name)
# -> 1017             return func(*args, **kwargs)
#    1018
#    1019         def wrapper(*args, **kwargs):
#
# ~/Documents/Research/PyDatAnalysis/src/DatObject/Attributes/DatAttribute.py in check_init(self)
#     158             group = self.hdf.get(self.group_name)
#     159         if group.attrs.get('initialized', False) is False:
# --> 160             self._initialize()
#     161
#     162     @with_hdf_write
#
# ~/Documents/Research/PyDatAnalysis/src/HDF_Util.py in wrapper(*args, **kwargs)
#    1426         container = _get_obj_hdf_container(self)
#    1427         wrapped_func = container.function_wrapper(func, mode_=mode_, group_name=getattr(self, 'group_name', None))  # TODO: Just need to make sure container.set_group is called!
# -> 1428         ret = wrapped_func(*args, **kwargs)
#    1429         # ret = func(*args, **kwargs)
#    1430         return ret
#
# ~/Documents/Research/PyDatAnalysis/src/HDF_Util.py in wrapper(*args, **kwargs)
#    1073                             # Easy to just have this be the default end state (even if about to be closed immediately after)
#    1074                     else:  # Already in write mode, so don't close hdf which was opened in 'with' by starting write thread
# -> 1075                         ret = call_func(*args, **kwargs)
#    1076                 elif mode == 'r':
#    1077                     ret = call_func(*args, **kwargs)
#
# ~/Documents/Research/PyDatAnalysis/src/HDF_Util.py in call_func(*args, **kwargs)
#    1015         def call_func(*args, **kwargs):
#    1016             self.set_group(group_name=group_name)
# -> 1017             return func(*args, **kwargs)
#    1018
#    1019         def wrapper(*args, **kwargs):
#
# ~/Documents/Research/PyDatAnalysis/src/DatObject/Attributes/DatAttribute.py in _initialize(self)
#     162     @with_hdf_write
#     163     def _initialize(self):
# --> 164         self.initialize_minimum()
#     165         self._write_default_group_attrs()
#     166         assert self.initialized == True
#
# ~/Documents/Research/PyDatAnalysis/src/DatObject/Attributes/Logs.py in initialize_minimum(self)
#     133         self._init_babydac()
#     134         self._init_fastdac()
# --> 135         self._init_awg()
#     136         self._init_temps()
#     137         self._init_mags()
#
# ~/Documents/Research/PyDatAnalysis/src/HDF_Util.py in wrapper(*args, **kwargs)
#    1426         container = _get_obj_hdf_container(self)
#    1427         wrapped_func = container.function_wrapper(func, mode_=mode_, group_name=getattr(self, 'group_name', None))  # TODO: Just need to make sure container.set_group is called!
# -> 1428         ret = wrapped_func(*args, **kwargs)
#    1429         # ret = func(*args, **kwargs)
#    1430         return ret
#
# ~/Documents/Research/PyDatAnalysis/src/HDF_Util.py in wrapper(*args, **kwargs)
#    1073                             # Easy to just have this be the default end state (even if about to be closed immediately after)
#    1074                     else:  # Already in write mode, so don't close hdf which was opened in 'with' by starting write thread
# -> 1075                         ret = call_func(*args, **kwargs)
#    1076                 elif mode == 'r':
#    1077                     ret = call_func(*args, **kwargs)
#
# ~/Documents/Research/PyDatAnalysis/src/HDF_Util.py in call_func(*args, **kwargs)
#    1015         def call_func(*args, **kwargs):
#    1016             self.set_group(group_name=group_name)
# -> 1017             return func(*args, **kwargs)
#    1018
#    1019         def wrapper(*args, **kwargs):
#
# ~/Documents/Research/PyDatAnalysis/src/DatObject/Attributes/Logs.py in _init_awg(self)
#     173         awg_dict = dictor(sweeplogs, 'FastDAC.AWG', None)
#     174         if awg_dict:
# --> 175             InitLogs.set_awg(group, awg_dict)
#     176
#     177     @with_hdf_write
#
# ~/Documents/Research/PyDatAnalysis/src/DatObject/Attributes/Logs.py in set_awg(group, awg_json)
#     516         if awg_json is not None:
#     517             # Simplify and shorten names
# --> 518             awg_data = awg_from_json(awg_json)
#     519
#     520             # Store in NamedTuple
#
# ~/Documents/Research/PyDatAnalysis/src/DatObject/Attributes/Logs.py in awg_from_json(awg_json)
#     639         waves = dictor(awg_json, 'AW_Waves', '')
#     640         dacs = dictor(awg_json, 'AW_Dacs', '')
# --> 641         d['outputs'] = {int(k): [int(val) for val in list(v.strip())] for k, v in zip(waves.split(','), dacs.split(','))}  # e.g. {0: [1,2], 1: [3]}
#     642         d['wave_len'] = dictor(awg_json, 'waveLen')
#     643         d['num_adcs'] = dictor(awg_json, 'numADCs')
#
# AttributeError: 'datetime.datetime' object has no attribute 'split'
